# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\samra\OneDrive\Documents\phython\Session 5\DATASETS\age2.csv")
df.head(6)
# Out:
#    Age  Degrees  Income
# 0   50        5    5000
# 1   60        3    4500
# 2   10        1    7000
# 3   20        2    6000
# 4   40        7    3500
# 5   80        9    2000

# %%
import matplotlib.pyplot as plt
plt.scatter(df['Age'],df['Income'])
plt.xlabel('Age')
plt.ylabel('Income')
plt.show()

# %%
plt.scatter(df['Degrees'],df['Income'])
plt.xlabel('Degrees')
plt.ylabel('Income')
plt.show()

# %%
x = df[['Age', 'Degrees']]
y = df['Income']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x,y,test_size=0.3,random_state=0)
X_train
# Out:
#    Age  Degrees
# 1   60        3
# 3   20        2
# 0   50        5
# 4   40        7

# %%
X_test
# Out:
#    Age  Degrees
# 5   80        9
# 2   10        1

# %%
from sklearn.linear_model import LinearRegression
clf = LinearRegression()

# %%
clf.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
clf.predict(X_test)
# Out:
# array([2314.81481481, 6555.55555556])

# %%
clf.score(X_test, y_test)
# Out:
# 0.9762688614540465

# %%
clf.coef_
# Out:
# array([ -20.37037037, -351.85185185])

# %%
clf.intercept_
# Out:
# np.float64(7111.1111111111095)

# %%
y_pred = clf.predict(x)
y_pred
# Out:
# array([4333.33333333, 4833.33333333, 6555.55555556, 6000.        ,
#        3833.33333333, 2314.81481481])

# %%
import seaborn as sns
sns.regplot(x=y, y=y_pred)
# Out:
# <Axes: xlabel='Income'>
